# %%
#for step1 step3
import openpyxl 
#for step2
import pandas as pd 
#for step4  step5
import win32com.client 

#參數輸入
#cmonth輸入202012_ / 202101_ ....
cmonth = '202101_'
#工作表的位置
workbook_path=r'C:\Users\jlliao1985\CHT Box\gccbn50205\106 洞察分析_觀光\桃園景點遊憩\2020桃園景點遊憩\pytohn_code\桃園遊憩據點交付資料_test.xlsx'
#複製頁籤的檔案(之前交付過的)
path1 = r'C:\Users\jlliao1985\CHT Box\gccbn50205\106 洞察分析_觀光\桃園景點遊憩\2020桃園景點遊憩\桃園遊憩據點交付資料\桃園遊憩據點交付資料_110年01月份.xlsx'
#完成檔案之儲存路徑
save_path=r'C:\Users\jlliao1985\CHT Box\gccbn50205\106 洞察分析_觀光\桃園景點遊憩\2020桃園景點遊憩\pytohn_code\桃園遊憩據點交付資料_.xlsx'


#Step1. 刪除現有sheet
workbook1 = openpyxl.load_workbook(workbook_path)
print(workbook1.sheetnames)

del workbook1['頁籤說明']

workbook1.save(workbook_path)
print("")
print("Step1. 刪除現有原始資料表 completed")


#Step2. 插入csv
def write_excel(filename,sheetname,csvpath):
    with pd.ExcelWriter(filename,engine='openpyxl',mode='a') as writer:
        workBook = writer.book
        try:
            workBook.remove(workBook[sheetname])
        except:
             print("")
            #print("Workshhet doesn't exsit")
        finally:
            read_file= pd.read_csv(csv_path)
            read_file.to_excel (writer , index = False, header=True,sheet_name=sheetname)
            writer.save()



#在 Python 中，字串的最前方加上 r，代表的是這是一個完整的字串，所有文字都是符號，不會有其他意思。
#字串前面加上f，啟動f-string 可以插入字串變數 (此處為cmonth)
#順序04 03 02 01 23 11 14 19 21方便後面排序

#04居住人口統計
csv_path = rf'C:\Users\jlliao1985\CHT Box\gccbn50205\106 洞察分析_觀光\桃園景點遊憩\2020桃園景點遊憩\pytohn_code\month_temp_csv\{cmonth}04.csv'
#print(csv_path)
write_excel(workbook_path,'4.居住人口統計',csv_path)
print("04居住人口統計插入完畢")

#03工作人口統計
csv_path = rf'C:\Users\jlliao1985\CHT Box\gccbn50205\106 洞察分析_觀光\桃園景點遊憩\2020桃園景點遊憩\pytohn_code\month_temp_csv\{cmonth}03.csv'
#print(csv_path)
write_excel(workbook_path,'3.工作人口統計',csv_path)
print("03工作人口統計插入完畢")

#02日大表
csv_path = rf'C:\Users\jlliao1985\CHT Box\gccbn50205\106 洞察分析_觀光\桃園景點遊憩\2020桃園景點遊憩\pytohn_code\month_temp_csv\{cmonth}02.csv'
#print(csv_path)
write_excel(workbook_path,'2.日大表',csv_path)
print("02日大表插入完畢")

#01月大表
csv_path = rf'C:\Users\jlliao1985\CHT Box\gccbn50205\106 洞察分析_觀光\桃園景點遊憩\2020桃園景點遊憩\pytohn_code\month_temp_csv\{cmonth}01.csv'
#print(csv_path)
write_excel(workbook_path,'1.月大表',csv_path)
print("01月大表插入完畢")

#23.6-8點日大表(三景點)
csv_path = rf'C:\Users\jlliao1985\CHT Box\gccbn50205\106 洞察分析_觀光\桃園景點遊憩\2020桃園景點遊憩\pytohn_code\month_temp_csv\{cmonth}23.csv'
#print(csv_path)
write_excel(workbook_path,'23.6-8點日大表(三景點)',csv_path)
print("23.6-8點日大表(三景點)插入完畢")


#11月國籍
csv_path = rf'C:\Users\jlliao1985\CHT Box\gccbn50205\106 洞察分析_觀光\桃園景點遊憩\2020桃園景點遊憩\pytohn_code\month_temp_csv\{cmonth}11.csv'
#print(csv_path)
write_excel(workbook_path,'11.國籍 (月)',csv_path)
print("11.國籍(月)插入完畢")

#14月夜宿桃園
csv_path = rf'C:\Users\jlliao1985\CHT Box\gccbn50205\106 洞察分析_觀光\桃園景點遊憩\2020桃園景點遊憩\pytohn_code\month_temp_csv\{cmonth}14.csv'
#print(csv_path)
write_excel(workbook_path,'14.月夜宿桃園',csv_path)
print("14.月夜宿桃園插入完畢")

#19日國籍
csv_path = rf'C:\Users\jlliao1985\CHT Box\gccbn50205\106 洞察分析_觀光\桃園景點遊憩\2020桃園景點遊憩\pytohn_code\month_temp_csv\{cmonth}19.csv'
#print(csv_path)
write_excel(workbook_path,'19.國籍',csv_path)
print("19.日國籍插入完畢")

#21日夜宿桃園
csv_path = rf'C:\Users\jlliao1985\CHT Box\gccbn50205\106 洞察分析_觀光\桃園景點遊憩\2020桃園景點遊憩\pytohn_code\month_temp_csv\{cmonth}21.csv'
#print(csv_path)
write_excel(workbook_path,'21.當日夜宿桃園',csv_path)
print("21.日夜宿桃園插入完畢")


print("Step2. 插入當月各分頁csv data  completed")

#Step3 複製頁籤說明
wb1 = openpyxl.load_workbook(filename=path1)
ws1 = wb1.worksheets[0]

wb2 = openpyxl.load_workbook(filename=workbook_path)
ws2 = wb2.create_sheet(ws1.title)

for row in ws1:
    for cell in row:
        ws2[cell.coordinate].value = cell.value

wb2.save(workbook_path)

print("Step3. copy 頁籤說明 completed")


#Step4. 調整各表順序
#https://stackoverflow.com/questions/26935793/python-2-7-win32com-client-move-a-worksheet-from-one-workbook-to-another


excel = win32com.client.Dispatch('Excel.Application')
excel.Visible = True
wb = excel.Workbooks.Open(Filename=workbook_path, ReadOnly='False')
for worksheet in wb.Sheets:
    print(worksheet.Name)
    #AFfter會移到另一張表，所以用Before
    if worksheet.Name == "4.居住人口統計":
        worksheet.Move(Before=wb.Sheets("5.每月重覆人次 "))
    if worksheet.Name == "3.工作人口統計":
        worksheet.Move(Before=wb.Sheets("4.居住人口統計"))
    if worksheet.Name == "2.日大表":
        worksheet.Move(Before=wb.Sheets("3.工作人口統計"))
    if worksheet.Name == "1.月大表":
        worksheet.Move(Before=wb.Sheets("2.日大表")) 
    if worksheet.Name == "23.6-8點日大表(三景點)  ":
        worksheet.Move(Before=wb.Sheets("11.國籍 (月)"))
    if worksheet.Name == "頁籤說明":
        worksheet.Move(Before=wb.Sheets("1.月大表"))

        
#Step5. 新增交叉樞紐篩選器
#https://stackoverflow.com/questions/53991420/create-slicer-object-in-excel-via-python
#https://stackoverflow.com/questions/50271205/excel-pivot-table-filter-in-python-via-win32com

#重新整理
wb.RefreshAll() 

#定義slicer名稱List
slicer_list = []

def create_Slicer(worksheet_name,Field_Name,slicer_name,Top=100,Left=500,Width=210,Height=500):
    
    ws = wb.Worksheets(worksheet_name)
    #先建立slicer cache物件
    #第四個參數 XlSlicerCacheType    xlSlicer	1  xlTimeline	2
    SLcache = wb.SlicerCaches.Add2(ws.PivotTables(1),Field_Name,slicer_name,1)
    
    #將cache物件加到表上
    SLcache.Slicers.Add(ws,Name=slicer_name,Top=10,Height=1300)
    
    slicer_list.append(slicer_name)

    return SLcache

#slicer_name不能重複
create_Slicer('6.每日不重覆人數  ','景點','dly_cnt_slicer')
create_Slicer('11.國籍 (月)_樞紐','a.spot','country_slicer')
create_Slicer('14.月夜宿桃園_樞紐','景點','monthly_night_slicer')
create_Slicer('16.性別  ','景點','dly_sex_slicer')    
create_Slicer('17.年齡層','景點','dly_age_slicer')    
create_Slicer('18.居住縣市 ','景點','dly_live_country_slicer')    
create_Slicer('19.國籍_樞紐','a.spot','dly_country_slicer')   
create_Slicer('20.日平均停留時間 ','a.spot','dly_time_slicer_spot')   
create_Slicer('20.日平均停留時間 ','a.ctype','dly_time_slicer_ctpye')   
create_Slicer('21.當日夜宿桃園_樞紐','景點','dly_night_slicer')   
create_Slicer('22.過夜率_日','景點','dly_nightrate_slicer') 



#處slicer預設都是全選，只選青埔休閒遊憩區
for item in slicer_list:
    if item != 'dly_time_slicer_ctpye' and item != 'country_slicer' and item != 'dly_country_slicer':
        print ("'"+item+"'")
        #wb.SlicerCaches("'"+item+"'").SlicerItems("永安漁港").Selected=False
        wb.SlicerCaches(item).SlicerItems("三坑老街").Selected=False
        wb.SlicerCaches(item).SlicerItems("大溪月眉休閒農業區").Selected=False
        wb.SlicerCaches(item).SlicerItems("大溪老街").Selected=False
        wb.SlicerCaches(item).SlicerItems("小烏來風景特定區").Selected=False
        wb.SlicerCaches(item).SlicerItems("五酒桶山步道").Selected=False
        wb.SlicerCaches(item).SlicerItems("永安漁港").Selected=False
        wb.SlicerCaches(item).SlicerItems("石門水庫風景區").Selected=False
        wb.SlicerCaches(item).SlicerItems("竹圍漁港").Selected=False
        wb.SlicerCaches(item).SlicerItems("角板山").Selected=False
        wb.SlicerCaches(item).SlicerItems("拉拉山").Selected=False
        wb.SlicerCaches(item).SlicerItems("虎頭山風景特定區").Selected=False
        wb.SlicerCaches(item).SlicerItems("許厝港溼地").Selected=False
        wb.SlicerCaches(item).SlicerItems("慈湖").Selected=False
        wb.SlicerCaches(item).SlicerItems("新屋綠色走廊").Selected=False
        wb.SlicerCaches(item).SlicerItems("農博環境教育園區").Selected=False
        wb.SlicerCaches(item).SlicerItems("龍潭大池").Selected=False
        wb.SlicerCaches(item).SlicerItems("羅浮").Selected=False
        wb.SlicerCaches(item).SlicerItems("觀音蓮花園休閒農業區").Selected=False
        wb.SlicerCaches(item).SlicerItems("觀音濱海遊憩區").Selected=False
        #print ("'"+item+"'")
        #wb.SlicerCaches(item).ClearManualFilter


#Slicer預設值
wb.SlicerCaches("dly_time_slicer_ctpye").SlicerItems("來台旅客").Selected=False

wb.SaveAs(save_path)
excel.Quit()

#把最後幾張原始資料表隱藏 
#20. 新增兩個，會重疊在一起，手動移開
# Out:
# ['5.每月重覆人次 ', '6.每日不重覆人數  ', '7.當月不重覆人數 ', '8.性別比例(月) ', '9.年齡比例(月)  ', '10.居住地比例(月)', '11.國籍 (月)_樞紐', '12.平均停留時間 (月)', '13.重遊率(月) ', '14.月夜宿桃園_樞紐', '15.過夜率_月', '16.性別  ', '17.年齡層', '18.居住縣市 ', '19.國籍_樞紐', '20.日平均停留時間 ', '21.當日夜宿桃園_樞紐', '22.過夜率_日', '4.居住人口統計', '3.工作人口統計', '2.日大表', '1.月大表', '23.6-8點日大表(三景點)', '11.國籍 (月)', '14.月夜宿桃園', '19.國籍', '21.當日夜宿桃園', '頁籤說明']
#
# Step1. 刪除現有原始資料表 completed
# 04居住人口統計插入完畢
# 03工作人口統計插入完畢
# 02日大表插入完畢
# 01月大表插入完畢
# 23.6-8點日大表(三景點)插入完畢
# 11.國籍(月)插入完畢
# 14.月夜宿桃園插入完畢
# 19.日國籍插入完畢
# 21.日夜宿桃園插入完畢
# Step2. 插入當月各分頁csv data  completed
# Step3. copy 頁籤說明 completed
# 5.每月重覆人次
# 6.每日不重覆人數
# 7.當月不重覆人數
# 8.性別比例(月)
# 9.年齡比例(月)
# 10.居住地比例(月)
# 11.國籍 (月)_樞紐
# 12.平均停留時間 (月)
# 13.重遊率(月)
# 14.月夜宿桃園_樞紐
# 15.過夜率_月
# 16.性別
# 17.年齡層
# 18.居住縣市
# 19.國籍_樞紐
# 20.日平均停留時間
# 21.當日夜宿桃園_樞紐
# 22.過夜率_日
# 4.居住人口統計
# 3.工作人口統計
# 2.日大表
# 1.月大表
# 23.6-8點日大表(三景點)
# 11.國籍 (月)
# 14.月夜宿桃園
# 19.國籍
# 21.當日夜宿桃園
# 頁籤說明
# 'monthly_night_slicer'
# 'dly_sex_slicer'
# 'dly_age_slicer'
# ...
